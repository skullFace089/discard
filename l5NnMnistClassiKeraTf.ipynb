# %%
# Importing necessary libraries
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load and preprocess the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Flatten the 28x28 images into 1D arrays
x_train = x_train.reshape((x_train.shape[0], -1))
x_test = x_test.reshape((x_test.shape[0], -1))

# One-hot encode the target labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Build the MLP model
model = Sequential()
model.add(Dense(128, input_shape=(784,), activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2652 - accuracy: 0.9233 - val_loss: 0.1382 - val_accuracy: 0.9619
# Epoch 2/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1129 - accuracy: 0.9655 - val_loss: 0.1182 - val_accuracy: 0.9635
# Epoch 3/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0787 - accuracy: 0.9760 - val_loss: 0.0975 - val_accuracy: 0.9700
# Epoch 4/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0595 - accuracy: 0.9811 - val_loss: 0.0996 - val_accuracy: 0.9710
# Epoch 5/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0461 - accuracy: 0.9850 - val_loss: 0.1056 - val_accuracy: 0.9721
# Epoch 6/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0369 - accuracy: 0.9878 - val_loss: 0.1323 - val_accuracy: 0.9644
# Epoch 7/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0307 - accuracy: 0.9898 - val_loss: 0.1054 - val_accuracy: 0.9751
# Epoch 8/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0245 - accuracy: 0.9919 - val_loss: 0.1246 - val_accuracy: 0.9702
# Epoch 9/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0226 - accuracy: 0.9924 - val_loss: 0.1108 - val_accuracy: 0.9745
# Epoch 10/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.1076 - val_accuracy: 0.9756
# 313/313 [==============================] - 0s 724us/step - loss: 0.0924 - accuracy: 0.9779
# Test Accuracy: 97.79%

# %%
# import matplotlib.pyplot as plt
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Plot training and validation accuracy curves
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy Curves')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.1170 - val_accuracy: 0.9737
# Epoch 2/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.1348 - val_accuracy: 0.9695
# Epoch 3/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.1221 - val_accuracy: 0.9755
# Epoch 4/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0128 - accuracy: 0.9954 - val_loss: 0.1406 - val_accuracy: 0.9739
# Epoch 5/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.1701 - val_accuracy: 0.9700
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.1321 - val_accuracy: 0.9772
# Epoch 7/10
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.1360 - val_accuracy: 0.9734
# Epoch 8/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.1270 - val_accuracy: 0.9779
# Epoch 9/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.1437 - val_accuracy: 0.9756
# Epoch 10/10
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.1533 - val_accuracy: 0.9739
